# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay-datascience/sample_repo/blob/master/Male_female_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/gender_classification.csv')
df
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
df.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender'],
#       dtype='object')

# %%
df.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
df.tail()
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long  gender
# 4996          0                          0  Female
# 4997          0                          0  Female
# 4998          0                          0  Female
# 4999          0                          0  Female
# 5000          1                          1    Male

# %%
df.dtypes
# Out:
# long_hair                      int64
# forehead_width_cm            float64
# forehead_height_cm           float64
# nose_wide                      int64
# nose_long                      int64
# lips_thin                      int64
# distance_nose_to_lip_long      int64
# gender                        object
# dtype: object

# %%
df.isna().sum()
# Out:
# long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[ 1. , 11.8,  6.1, ...,  0. ,  1. ,  1. ],
#        [ 0. , 14. ,  5.4, ...,  0. ,  1. ,  0. ],
#        [ 0. , 11.8,  6.3, ...,  1. ,  1. ,  1. ],
#        ...,
#        [ 1. , 12.9,  5.7, ...,  0. ,  0. ,  0. ],
#        [ 1. , 13.2,  6.2, ...,  0. ,  0. ,  0. ],
#        [ 1. , 15.4,  5.4, ...,  1. ,  1. ,  1. ]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array(['Male', 'Female', 'Male', ..., 'Female', 'Female', 'Male'],
#       dtype=object)

# %%
df.size
# Out:
# 40008

# %%
df.shape
# Out:
# (5001, 8)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
# array([[ 1. , 13. ,  6.4, ...,  0. ,  0. ,  0. ],
#        [ 1. , 11.8,  5.1, ...,  0. ,  1. ,  1. ],
#        [ 1. , 12. ,  5.5, ...,  1. ,  1. ,  1. ],
#        ...,
#        [ 1. , 13.4,  5.5, ...,  0. ,  0. ,  0. ],
#        [ 1. , 13.7,  5.7, ...,  1. ,  1. ,  1. ],
#        [ 1. , 15.1,  5.4, ...,  1. ,  1. ,  1. ]])

# %%
x_test
# Out:
# array([[ 1. , 12.8,  6.3, ...,  0. ,  1. ,  0. ],
#        [ 1. , 12.3,  5.8, ...,  1. ,  1. ,  1. ],
#        [ 1. , 11.5,  5.4, ...,  0. ,  0. ,  0. ],
#        ...,
#        [ 1. , 11.6,  5.8, ...,  1. ,  1. ,  1. ],
#        [ 1. , 13.3,  5.4, ...,  0. ,  1. ,  0. ],
#        [ 0. , 13.7,  5.1, ...,  1. ,  1. ,  1. ]])

# %%
y_train
# Out:
# array(['Female', 'Female', 'Male', ..., 'Female', 'Male', 'Male'],
#       dtype=object)

# %%
y_test
# Out:
# array(['Female', 'Male', 'Female', ..., 'Male', 'Female', 'Male'],
#       dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
knn=KNeighborsClassifier(n_neighbors=7)
bayes=GaussianNB()
sup=SVC()
lst=[knn,bayes,sup]

# %%
for i in lst:
  print("The model is: ",i)
  i.fit(x_train,y_train)
  y_pred=i.predict(x_test)
  cm=confusion_matrix(y_test,y_pred)
  print("The confusion_matrix of model:",i, "is: ")
  print(cm)
  score=accuracy_score(y_test,y_pred)
  print("The accuracy_score of model:",i,"is: ")
  print(score)
  cr=classification_report(y_test,y_pred)
  print("The classification_report of model:",i,"is: ")
  print(cr)
# Out:
# The model is:  KNeighborsClassifier(n_neighbors=7)
# The confusion_matrix of model: KNeighborsClassifier(n_neighbors=7) is:
# [[731  14]
#  [ 36 720]]
# The accuracy_score of model: KNeighborsClassifier(n_neighbors=7) is:
# 0.966688874083944
# The classification_report of model: KNeighborsClassifier(n_neighbors=7) is:
#               precision    recall  f1-score   support
#
#       Female       0.95      0.98      0.97       745
#         Male       0.98      0.95      0.97       756
#
#     accuracy                           0.97      1501
#    macro avg       0.97      0.97      0.97      1501
# weighted avg       0.97      0.97      0.97      1501
#
# The model is:  GaussianNB()
# The confusion_matrix of model: GaussianNB() is:
# [[723  22]
#  [ 21 735]]
# The accuracy_score of model: GaussianNB() is:
# 0.9713524317121919
# The classification_report of model: GaussianNB() is:
#               precision    recall  f1-score   support
#
# ...

# %%
print(i.predict(scaler.transform([[1,10.4,6.3,1,0,0,1]])))
# Out:
# ['Male']
